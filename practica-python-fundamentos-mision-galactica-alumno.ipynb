# %% [markdown]
# # 🚀 Misión Galáctica — Fundamentos Python (ALUMNO)
#
# Versión para practicar: retos claros, pistas y checks rápidos.

# %% [markdown]
# ## Cómo usar este cuaderno
# 1. Completa el código en cada reto.
# 2. Ejecuta el check si existe.
# 3. Si falla, corrige y vuelve a intentar.

# %%
from IPython.display import HTML, display
display(HTML("<div style='padding:10px;border-radius:10px;background:#1f2937;color:#fff'>🛰️ Iniciando entrenamiento de la tripulación...</div>"))
# Out:
# <div style='padding:10px;border-radius:10px;background:#1f2937;color:#fff'>🛰️ Iniciando entrenamiento de la tripulación...</div>

# %% [markdown]
# ## Reto 1 — Variables y tipos
# Crea estas variables: `capitana` (texto), `energia` (número), `escudo_activo` (booleano).

# %%
# TODO
capitana = 'texto'
energia = 0
escudo_activo = False
print(capitana, energia, escudo_activo)
# Out:
# texto 0 False

# %%
assert isinstance(capitana, str), 'capitana debe ser texto'
assert isinstance(energia, (int, float)), 'energia debe ser número'
assert isinstance(escudo_activo, bool), 'escudo_activo debe ser booleano'
print('✅ Reto 1 OK')
# Out:
# ✅ Reto 1 OK

# %% [markdown]
# ## Reto 2 — Condicionales
# Muestra `Aterrizaje autorizado` si `energia >= 40` y `escudo >= 50`; si no, denegado.

# %%
energia = 45
escudo = 60
if energia > 40:
    print("Acceso permitido")
elif escudo < 50:
    print("Acceso permitido")
else:
    print("No puedes pasar")
# TODO: escribe aquí el if/else
# Out:
# Acceso permitido

# %% [markdown]
# ## Reto 3 — Bucles
# Recorre `modulos` y muestra `Revisando <modulo>...`

# %%
modulos = ['motor', 'radar', 'escudos', 'comunicaciones']
# TODO: for ...
for intem in modulos:
    print(intem)
# Out:
# motor
# radar
# escudos
# comunicaciones

# %% [markdown]
# ## Reto 4 — Funciones
# Completa `puntos_mision` para que devuelva `tareas*10 + bonus`.

# %%
def puntos_mision(tareas=6, bonus=12):
    # TODO
    resultado = tareas*10 + bonus
    return resultado
print('Puntos:', puntos_mision(6, 12))
print("Puntos ():", puntos_mision())
# Out:
# Puntos: 72
# Puntos (): 72

# %%
assert puntos_mision(2, 5) == 25, 'Revisa la fórmula de la función'
print('✅ Reto 4 OK')
# Out:
# ✅ Reto 4 OK

# %% [markdown]
# ## Reto 5 — Diccionarios
# Crea un diccionario `pilota` con `nombre`, `rol`, `nivel` y muestra nombre + rol.

# %%
pilota = {"nombre": "Juan", "rol": "Piloto de naves", "nivel": 5}
print(f"{pilota['nombre']} asciende a {pilota['rol']}")
# Out:
# Juan asciende a Piloto de naves

# %% [markdown]
# ## Reto 6 (creativo) — Barra de progreso
# Asigna un valor a `progreso` (0-100) y visualiza una barra.

# %%
progreso = 39  # TODO: cambia valor
display(HTML(f"<div style='font-family:system-ui'><p>Progreso: <b>{progreso}%</b></p><div style='width:320px;height:18px;border-radius:10px;background:#ddd'><div style='width:{progreso}%;height:18px;border-radius:10px;background:#22c55e'></div></div></div>"))
# Out:
# <div style='font-family:system-ui'><p>Progreso: <b>39%</b></p><div style='width:320px;height:18px;border-radius:10px;background:#ddd'><div style='width:39%;height:18px;border-radius:10px;background:#22c55e'></div></div></div>

# %% [markdown]
# ## Reto 7 (humor) — Ruleta galáctica
# Usa `random.choice` para escoger un planeta y mostrar un mensaje.

# %%
import random
planetas = ['🪐 Saturno', '🔴 Marte', '🌕 Luna', '🌌 Nebulosa X']
# TODO: elige destino y muestra mensaje
print(f"Preparando ajustes de la nave... ¡Nuestro planeta de destino es...  {destino}!")
# Out:
# 🔴 Marte

# %% [markdown]
# ## Meta final
# Si completas los 7 retos, ya tienes base para entrar con más seguridad en pandas y limpieza de datos. ✅
